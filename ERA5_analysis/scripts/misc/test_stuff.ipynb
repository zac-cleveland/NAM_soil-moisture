# %% [markdown]
# This script is used for random testing and analysis for which I don't want to create a unique script, but want to have a way to reference my process if I have to end a session or get disconnected.

# %%
# import functions
# OS interaction and time
import os
import sys
import cftime
import datetime
import time
import glob
import dask
import dask.bag as db
from dask.diagnostics import ProgressBar
from dask.distributed import Client
from dask_jobqueue import PBSCluster
import calendar
import importlib

# math and data
import math
import numpy as np
import netCDF4 as nc
import xarray as xr
from functools import partial
import scipy as sp
import scipy.linalg
from scipy.signal import detrend
import pandas as pd
import pickle as pickle
from sklearn import linear_model
import matplotlib.patches as mpatches
from shapely.geometry.polygon import LinearRing
import statsmodels.stats.multitest as multitest

# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker
import matplotlib.colors as mcolors
from matplotlib.gridspec import GridSpec
import matplotlib.image as mpimg
from matplotlib.colors import TwoSlopeNorm
import matplotlib.cm as cm

from matplotlib.ticker import FormatStrFormatter
from mpl_toolkits.axes_grid1.axes_divider import HBoxDivider
import mpl_toolkits.axes_grid1.axes_size as Size
from mpl_toolkits.axes_grid1 import make_axes_locatable

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point

# random
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# paths to various directories
rda_era5_path = '/glade/campaign/collections/rda/data/ds633.0/'  # base path to ERA5 data on derecho
my_era5_path = '/glade/u/home/zcleveland/scratch/ERA5/'  # path to subset data
misc_data_path = '/glade/u/home/zcleveland/scratch/misc_data/'  # path to misc data
plot_out_path = '/glade/u/home/zcleveland/NAM_soil-moisture/ERA5_analysis/plots/'  # path to generated plots
scripts_main_path = '/glade/u/home/zcleveland/NAM_soil-moisture/scripts_main/'  # path to my dicts, lists, and functions

# import variable lists and dictionaries
if scripts_main_path not in sys.path:
    sys.path.insert(0, scripts_main_path)  # path to file containing these lists/dicts
if 'get_var_data' in sys.modules:
    importlib.reload(sys.modules['get_var_data'])
if 'my_functions' in sys.modules:
    importlib.reload(sys.modules['my_functions'])
if 'my_dictionaries' in sys.modules:
    importlib.reload(sys.modules['my_dictionaries'])
if 'order_years' in sys.modules:
    importlib.reload(sys.modules['order_years'])

# import common functions that I've created
from get_var_data import get_var_data, get_var_files, open_var_data, subset_var_data, time_to_year_month_avg, time_to_year_month_sum, time_to_year_month
from my_functions import month_num_to_name, ensure_var_list
from order_years import order_years

# import lists and dictionaries
from my_dictionaries import (
sfc_instan_list, sfc_accumu_list, pl_var_list, derived_var_list, invar_var_list,
NAM_var_list, region_avg_list, flux_var_list, vector_var_list, misc_var_list,
var_dict, var_units, region_avg_dict, region_avg_coords, region_colors_dict
)

# %%
if __name__ == '__main__':
    main_var = 'onset'
    main_region = 'MeNmAz'
    main_months = None
    main_var_data = get_var_data(main_var, region='MeNmAz')
    sorted_years = order_years(main_var, main_region, main_months, main_var_data)
    if 'month' in main_var_data.dims:
        main_var_data = main_var_data.sel(month=main_months).mean('month', skipna=True)
    main_sorted_data = main_var_data.sel(year=sorted_years)
    main_sorted_data = (main_sorted_data - main_sorted_data.mean(skipna=True)) / main_sorted_data.std(skipna=True)
    
    var_list = [
        'swvl1', 'sd',
        'sshf', 'slhf',
        'z_thick_1000-500',
        'tcw', 'length', 'tp'
    ]
    var_regions = [
        'cp', 'cp',
        'cp', 'cp',
        'cp',
        'MeNmAz', 'MeNmAz', 'MeNmAz'
    ]
    var_months = [
        [3,4,5], [3,4,5],
        [4,5,6], [4,5,6],
        [6],
        [6,7], None, [6,7,8,9]
    ]
    var_data = [get_var_data(var, region) for var,region in zip(var_list,var_regions)]
    for i, month in enumerate(var_months):
        if 'month' in var_data[i].dims:
            var_data[i] = var_data[i].sel(month=month).mean('month', skipna=True)
    sorted_data = [da.sel(year=sorted_years) for da in var_data]
    sorted_data = [(da - da.mean(skipna=True)) / da.std(skipna=True) for da in sorted_data]
                
    var_colors = ['magenta', 'magenta', 'red', 'red', 'orange', 'blue', 'purple', 'blue']
    var_styles = ['-', '--', '-', '--', '-', '-', '-', '--']

    for i in range(len(sorted_data)):
        fig, ax = plt.subplots(figsize=(12,10))
        ax.plot(np.arange(40), main_sorted_data.values, label=f'{main_var}', color='black')
        xticks = [f"'{a.values}"[-2:] for a in sorted_years]
        ax.set_xticks(np.arange(40))
        ax.set_xticklabels(xticks)
        ax.xaxis.set_tick_params(labelrotation=45)
        ax2 = ax.twinx()
        ax2.plot(np.arange(40), sorted_data[i].values, label=f'{var_list[i]}', color='blue')
        fig.suptitle(f'{var_dict[var_list[i]]} sorted by: {var_dict[main_var]}')
        plt.legend()
        plt.show()

# %%
if __name__ == '__main__':
    var = 'length'
    region = 'MeNmAz'
    months = []
    var_data, sorted_years, ordered_data = run_ordered_years(var, region, months)

# %%
if __name__ == '__main__':
    var_list = ['onset', 'length', 'retreat', 'precipitation', 'precipitation-rate', 'tp', 'lsp', 'cp', 'tcw', 'cape']
    region = 'MeNmAz'
    months = [6, 7, 8, 9]
    max_years = {}
    for var in var_list:
        var_data, sorted_years, ordered_data = run_ordered_years(var, region, months)
        max_years.update({f'{var}': sorted_years})

# %%
# define a function to regress data
def regress_data(arr1, arr2):
    # mask out nan values
    mask = np.isfinite(arr1) & np.isfinite(arr2)
    arr1_mask = arr1[mask]
    arr2_mask = arr2[mask]

    # check that there are enough data points and not all x values are identical
    if len(np.unique(arr1_mask)) < 2:
        return np.nan, np.nan, np.nan, np.nan, np.nan, np.nan

    else:  # compute linear regression
        res = sp.stats.linregress(arr1_mask, arr2_mask)
        return res.slope, res.intercept, res.rvalue, res.pvalue, res.stderr, res.intercept_stderr


# define a function to mask data for detrending or correlating
def apply_regression(da1, da2, **kwargs):
    input_dims = kwargs.get('time_group', 'year')

    result = xr.apply_ufunc(
        regress_data, da1, da2,
        input_core_dims=[[input_dims], [input_dims]],
        output_core_dims=[[], [], [], [], [], []],
        vectorize=True,
        dask='parallelized',
        dask_gufunc_kwargs={'allow_rechunk': True},
        output_dtypes=[float, float, float, float, float, float]
    )
    regression_ds = xr.Dataset({
        'slope': result[0],
        'intercept': result[1],
        'rvalue': result[2],
        'pvalue': result[3],
        'stderr': result[4],
        'intercept_stderr': result[5]
    })
    return regression_ds

# %%
lon, lat = 242, 33.75

t2 = get_var_data('2t').sel(year=slice(1985,2020), latitude=lat, longitude=lon, month=[9, 10, 11]).mean('month', skipna=True)
d2 = get_var_data('2d').sel(year=slice(1985,2020), latitude=lat, longitude=lon, month=[9, 10, 11]).mean('month', skipna=True)
ssrd = get_var_data('ssr').sel(year=slice(1985,2020), latitude=lat, longitude=lon, month=[9, 10, 11]).mean('month', skipna=True)

t2_result = sp.stats.linregress(t2.year, t2)
t2_regression = t2_result.slope * t2.year + t2_result.intercept
d2_result = sp.stats.linregress(d2.year, d2)
d2_regression = d2_result.slope * d2.year + d2_result.intercept
ssrd_result = sp.stats.linregress(ssrd.year, ssrd)
ssrd_regression = ssrd_result.slope * ssrd.year + ssrd_result.intercept

fig, ax = plt.subplots(figsize=(12,10))
ax.plot(t2.year, t2.values, color='r', label='temperature', linestyle='-')
ax.plot(t2_regression.year, t2_regression.values, color='r', label='temperature', linestyle='--')

ax.plot(d2.year, d2.values, color='b', label='dew point', linestyle='-')
ax.plot(d2_regression.year, d2_regression.values, color='b', label='dew point', linestyle='--')

ax2 = ax.twinx()
ax2.plot(ssrd.year, ssrd.values, color='g', label='downward solar radiation', linestyle='-')
ax2.plot(ssrd_regression.year, ssrd_regression.values, color='g', label='downward solar radiation', linestyle='--')

plt.legend()
plt.show()
plt.close()

# %%
def detrend_data(arr):
    # mask out nan values
    arr_time = np.arange(0,len(arr))
    mask = np.isfinite(arr)
    arr_time_mask = arr_time[mask]
    arr_mask = arr[mask]

    # make sure the array is not full of non-finite values
    if len(arr_mask) == 0:
        arr_detrend = np.empty(len(arr))
        arr_detrend[:] = np.nan
    else:  # compute linear regression
        result = sp.stats.linregress(arr_time_mask, arr_mask)
        m, b = result.slope, result.intercept
        # detrend the data
        arr_detrend = arr - (m*arr_time + b)
    return arr_detrend


def apply_detrend(da, **kwargs):
    dims = kwargs.get('dims', 'year')

    da_detrend = xr.apply_ufunc(
        detrend_data, da,
        input_core_dims=[[dims]],
        output_core_dims=[[dims]],
        vectorize=True,
        dask='parallelized',
        # dask_gufunc_kwargs={'allow_rechunk': True},
        output_dtypes=[float]
    )
    return da_detrend

# %%
def apply_detrend(da, dim='year', deg=1):
    coeffs = da.polyfit(dim=dim, deg=deg, skipna=True).polyfit_coefficients
    trend = xr.polyval(coord=da[dim], coeffs=coeffs)
    return (da - trend)

# %%
def calc_zscore(da, **kwargs):
    dim = kwargs.get('dim', 'year')
    return (da - da.mean(dim=dim, skipna=True)) / (da.std(dim=dim, skipna=True))

# %%
def plot_max_min_heights(months, max_years, min_years, save_png=False, out_fn=None, dpi=300):
    # get height data
    # z_height = get_var_data('z_thick_1000-500', level=500).sel(month=month)
    # z_detrend = apply_detrend(z_height)
    # z_zscore = calc_zscore(z_detrend)
    # z_years = z_zscore.sel(year=years, drop=True)
    # z_mean = z_years.mean('year', skipna=True)
    z_height = get_var_data('z_thick_1000-500', level=500).sel(year=years, month=month, drop=True).mean('year', skipna=True)

    # get wind data
    u_wind = get_var_data('u', level=500).sel(month=month)
    u_detrend = apply_detrend(u_wind)
    u_zscore = calc_zscore(u_detrend)
    u_years = u_zscore.sel(year=years, drop=True)
    u_mean = u_years.mean('year', skipna=True)
    
    v_wind = get_var_data('v', level=500).sel(month=month)
    v_detrend = apply_detrend(v_wind)
    v_zscore = calc_zscore(v_detrend)
    v_years = v_zscore.sel(year=years, drop=True)
    v_mean = v_years.mean('year', skipna=True)

    # get moisture data
    tcw = get_var_data('tcw', level=500).sel(month=month)
    tcw_detrend = apply_detrend(tcw)
    tcw_zscore = calc_zscore(tcw_detrend)
    tcw_years = tcw_zscore.sel(year=years, drop=True)
    tcw_mean = tcw_years.mean('year', skipna=True)

    # set up plotting variables and levels
    cf_plot = z_height  # shaded
    cf_min = 5480
    cf_max = 5840
    cf_levels = np.arange(cf_min, cf_max+20, 20)
    cf_norm = plt.Normalize(cf_min, cf_max)

    cs_plot = z_height  # lined
    cs_min = 5480
    cs_max = 5840
    cs_levels = np.arange(cs_min, cs_max+20, 20)
    cs_norm = plt.Normalize(cs_min, cs_max)

    # make figure
    fig, ax = plt.subplots(figsize=(12, 12), subplot_kw=dict(projection=ccrs.PlateCarree()))

    cf = ax.contourf(cf_plot.longitude, cf_plot.latitude, cf_plot,
                     levels=cf_levels, cmap='seismic', norm=cf_norm, extend='both', alpha=0.7, linestyles='none', transform=ccrs.PlateCarree())

    cs = ax.contour(cs_plot.longitude, cs_plot.latitude, cs_plot,
                    levels=cs_levels, linewidths=1, linestyles='-', colors='black', transform=ccrs.PlateCarree())

    # # add moisture transport vectors
    # lats, lons = np.meshgrid(viwve_mean.latitude, viwve_mean.longitude, indexing='ij')
    # gs = 8
    # ax.quiver(lons[::gs,::gs], lats[::gs,::gs], viwve_mean[::gs,::gs], viwvn_mean[::gs,::gs],
    #           color='k', width=0.002)

    # add wind vectors
    lats, lons = np.meshgrid(u_mean.latitude, u_mean.longitude, indexing='ij')
    gs = 8
    q = ax.quiver(lons[::gs,::gs], lats[::gs,::gs], u_mean[::gs,::gs], v_mean[::gs,::gs],
              color='k', width=0.002)
    ax.quiverkey(q, X=0.3, Y=1.1, U=10, label='z-score = 1', labelpos='E')

    # add coastlines, state borders, and other features
    ax.coastlines(linewidth=0.5)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.5)
    ax.add_feature(cfeature.STATES, linewidth=0.5)
          
    c_label = plt.clabel(cs, inline=True, fontsize=8, fmt='%.0f')

    # plt.tight_layout()
    
    if not save_png:
        fp_split = out_fp.split('.')
        cbar_fp = '.'.join([fp_split[0]+'_cbar', fp_split[1]])
        plot_max_min_heights_colorbar(cf_min, cf_max, cbar_fp, dpi, save_cbar=False)
    else:
        plt.savefig(out_fp, dpi=dpi, bbox_inches='tight')
        fp_split = out_fp.split('.')
        cbar_fp = '.'.join([fp_split[0]+'_cbar', fp_split[1]])
        plot_max_min_heights_colorbar(cf_min, cf_max, cbar_fp, dpi, save_cbar=True)
    plt.show()
    plt.close()


# define a function to plot the color bar for the max/min heights
def plot_max_min_heights_colorbar(vmin, vmax, cbar_fp, dpi, save_cbar, **kwargs):
    fig, ax = plt.subplots(figsize=(10, 0.5))  # adjust figsize
    # define a custom colormap
    norm = plt.Normalize(vmin=vmin, vmax=vmax)
    cbar = plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap='seismic'),
                        orientation='horizontal', ax=ax, pad=0.02,
                        fraction=1, extend='both', label='zscore')
    ticks = np.arange(vmin*100, vmax*100+0.2*100, 0.2*100) / 100  # this is what I have to do to avoid rounding errors???
    cbar.set_ticks(ticks)
    cbar.set_ticklabels([f'{i:.1f}' for i in ticks])
    cbar.ax.yaxis.set_major_formatter(ticker.FixedFormatter([f'{i:.1f}' for i in ticks]))  
    plt.axis('off')  # turn off axis
    # plt.tight_layout()

    # save color bar as an image
    if save_cbar:
        plt.savefig(cbar_fp, dpi=dpi, bbox_inches='tight')
    plt.show()
    plt.close()
