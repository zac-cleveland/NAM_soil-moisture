# %%
import sys

import numpy as np
import netCDF4 as nc
import numpy.matlib
import datetime
import xarray as xr
from scipy import interpolate
from numpy import ma
from scipy import stats
import scipy.io as sio
import pickle as pickle
from sklearn import linear_model
import numpy.ma as ma
import matplotlib.patches as mpatches
from shapely.geometry.polygon import LinearRing

import scipy as sp
import pandas as pd

import time

from copy import copy 

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker

from matplotlib.ticker import FormatStrFormatter
from mpl_toolkits.axes_grid1.axes_divider import HBoxDivider
import mpl_toolkits.axes_grid1.axes_size as Size
from mpl_toolkits.axes_grid1 import make_axes_locatable

# OS interaction
import os
import sys
import cftime

import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point

from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

import matplotlib.colors as mcolors

import glob
import dask
import dask.bag as db

from scipy import interpolate

import statsmodels.stats.multitest as multitest

from matplotlib.gridspec import GridSpec
from cartopy.crs import EqualEarth, PlateCarree

# %%
era5_path = '/glade/campaign/collections/rda/data/ds633.0/'
out_path = '/glade/u/home/zcleveland/scratch/ERA5/dsw/'

# %%
# add variables to search and combine
var_list = [
    'lsp', # large scale precipitation
    'cp', # convective precipitation
    'sd', # snow depth
    'msl', # mean sea level pressure
    'tcc', # total cloud cover
    'stl1', # soil temp layer 1
    'stl2', # soil temp layer 2
    'stl3', # soil temp layer 3
    'stl4', # soil temp layer 4
    'swvl1', # soil volume water content layer 1
    'swvl2', # soil volume water content layer 2
    'swvl3', # soil volume water content layer 3
    'swvl4', # soil volume water content layer 4
    '2t', # 2 meter temp
    '2d', # 2 meter dew point
    'ishf', # instant surface heat flux
    'ie', # instant moisture flux
]

# %%
# set time array to loop through
years = np.arange(1980,2020)
months = np.arange(1,13)

# %%
# Loop through variables in var_directories and process each one
sub_vars = ['avg', 'max', 'min']

for var in var_list:
    
    if any([glob.glob(f'{out_path}{var}_*_avg.nc'),
        glob.glob(f'{out_path}{var}_*_min.nc'),
        glob.glob(f'{out_path}{var}_*_max.nc')]):
        
        print(f'found avg/max/min in {var}. processing...\n')
        
        for year in years:
            
            start_date = int(f'{year}01')
            end_date = int(f'{year}12')
            
            if (os.path.exists(f'{out_path}{var}_{start_date}_{end_date}_dsw.nc')):
                print(f'{out_path}{var}_{start_date}_{end_date}_dsw.nc already exists\n skipping...\n')

            else:
                print(f'{out_path}{var}_{start_date}_{end_date}_dsw.nc')
                data_list = []
                
                for sub_var in sub_vars:
   
                    files = glob.glob(f'{out_path}{var}_{start_date}_{end_date}_dsw_{sub_var}.nc')
                    files.sort()
                    
                    with dask.config.set(**{'array.slicing.split_large_chunks': True}):
                        ds = xr.open_mfdataset(files, concat_dim='time', combine='nested', parallel=True, chunks={'time': 'auto'})
                        var_xx = [varx for varx in ds.data_vars.keys() if f'{var.upper()}' in varx][0]
                        ds = ds.rename_vars({f'{var_xx}': f'{var_xx}_{sub_var.upper()}'})
                        data_list.append(ds)
                        
                # data_list
                # break
                
                print()
                print(f'merging data')
                data = xr.merge(data_list, compat='override')
                print(f'writing data\n')
                data.to_netcdf(f'{out_path}{var}_{start_date}_{end_date}_dsw.nc')
print(f'done')
# Out:
# found avg/max/min in sd. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/sd_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in msl. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/msl_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in tcc. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/tcc_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in stl1. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl1_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in stl2. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl2_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in stl3. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl3_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in stl4. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/stl4_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in swvl1. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl1_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in swvl2. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl2_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in swvl3. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl3_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in swvl4. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198101_198112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198201_198212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198301_198312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198401_198412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198501_198512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198601_198612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198701_198712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198801_198812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_198901_198912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199001_199012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199101_199112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199201_199212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199301_199312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199401_199412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199501_199512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199601_199612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199701_199712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199801_199812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_199901_199912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200001_200012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200101_200112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200201_200212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200301_200312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200401_200412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200501_200512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200601_200612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200701_200712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200801_200812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_200901_200912_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201001_201012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201101_201112_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201201_201212_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201301_201312_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201401_201412_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201501_201512_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201601_201612_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201701_201712_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201801_201812_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/swvl4_201901_201912_dsw.nc already exists
#  skipping...
#
# found avg/max/min in 2t. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198001_198012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198101_198112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198201_198212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198301_198312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198401_198412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198501_198512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198601_198612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198701_198712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198801_198812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_198901_198912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199001_199012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199101_199112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199201_199212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199301_199312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199401_199412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199501_199512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199601_199612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199701_199712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199801_199812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_199901_199912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200001_200012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200101_200112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200201_200212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200301_200312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200401_200412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200501_200512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200601_200612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200701_200712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200801_200812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_200901_200912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201001_201012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201101_201112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201201_201212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201301_201312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201401_201412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201501_201512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201601_201612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201701_201712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201801_201812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2t_201901_201912_dsw.nc
#
# merging data
# writing data
#
# found avg/max/min in 2d. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198001_198012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198101_198112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198201_198212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198301_198312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198401_198412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198501_198512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198601_198612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198701_198712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198801_198812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_198901_198912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199001_199012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199101_199112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199201_199212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199301_199312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199401_199412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199501_199512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199601_199612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199701_199712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199801_199812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_199901_199912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200001_200012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200101_200112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200201_200212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200301_200312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200401_200412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200501_200512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200601_200612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200701_200712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200801_200812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_200901_200912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201001_201012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201101_201112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201201_201212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201301_201312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201401_201412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201501_201512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201601_201612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201701_201712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201801_201812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/2d_201901_201912_dsw.nc
#
# merging data
# writing data
#
# found avg/max/min in ishf. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198001_198012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198101_198112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198201_198212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198301_198312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198401_198412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198501_198512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198601_198612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198701_198712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198801_198812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_198901_198912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199001_199012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199101_199112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199201_199212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199301_199312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199401_199412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199501_199512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199601_199612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199701_199712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199801_199812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_199901_199912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200001_200012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200101_200112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200201_200212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200301_200312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200401_200412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200501_200512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200601_200612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200701_200712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200801_200812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_200901_200912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201001_201012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201101_201112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201201_201212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201301_201312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201401_201412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201501_201512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201601_201612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201701_201712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201801_201812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ishf_201901_201912_dsw.nc
#
# merging data
# writing data
#
# found avg/max/min in ie. processing...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198001_198012_dsw.nc already exists
#  skipping...
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198101_198112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198201_198212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198301_198312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198401_198412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198501_198512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198601_198612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198701_198712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198801_198812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_198901_198912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199001_199012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199101_199112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199201_199212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199301_199312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199401_199412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199501_199512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199601_199612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199701_199712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199801_199812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_199901_199912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200001_200012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200101_200112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200201_200212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200301_200312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200401_200412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200501_200512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200601_200612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200701_200712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200801_200812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_200901_200912_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201001_201012_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201101_201112_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201201_201212_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201301_201312_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201401_201412_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201501_201512_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201601_201612_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201701_201712_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201801_201812_dsw.nc
#
# merging data
# writing data
#
# /glade/u/home/zcleveland/scratch/ERA5/dsw/ie_201901_201912_dsw.nc
#
# merging data
# writing data
#
# done
